# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
# Load the text file
with open("Gutenberg.txt", "r", encoding="utf-8") as f:
    text = f.read()

# Create a character-level vocabulary
chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = {ch: i for i, ch in enumerate(chars)}  # String to Integer mapping
itos = {i: ch for i, ch in enumerate(chars)}  # Integer to String mapping

# Encode the text into integers


def encode(s):
    return [stoi[c] for c in s]


def decode(l):
    return ''.join([itos[i] for i in l])


data = torch.tensor(encode(text), dtype=torch.long)

# Split into training and validation sets (90% train, 10% val)
n = int(0.9 * len(data))
train_data = data[:n]
val_data = data[n:]

# %%
class GPT(nn.Module):
    def __init__(self, vocab_size, block_size, n_embd, n_layer, n_head):
        super().__init__()
        self.token_embedding = nn.Embedding(vocab_size, n_embd)
        self.position_embedding = nn.Embedding(block_size, n_embd)
        self.blocks = nn.ModuleList([
            TransformerBlock(n_embd, n_head) for _ in range(n_layer)
        ])
        self.ln_f = nn.LayerNorm(n_embd)
        self.head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.size()
        pos = torch.arange(0, T, dtype=torch.long, device=idx.device).unsqueeze(0)

        tok_emb = self.token_embedding(idx)
        pos_emb = self.position_embedding(pos)
        x = tok_emb + pos_emb

        for block in self.blocks:
            x = block(x)

        x = self.ln_f(x)
        logits = self.head(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1))
            return logits, loss
        return logits

class TransformerBlock(nn.Module):
    def __init__(self, n_embd, n_head):
        super().__init__()
        self.attn = nn.MultiheadAttention(n_embd, n_head, batch_first=True)
        self.ln1 = nn.LayerNorm(n_embd)
        self.mlp = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.GELU(),
            nn.Linear(4 * n_embd, n_embd),
        )
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        attn_out, _ = self.attn(x, x, x)
        x = x + attn_out
        x = self.ln1(x)

        mlp_out = self.mlp(x)
        x = x + mlp_out
        x = self.ln2(x)

        return x

# %%
import time

# Hyperparameters
batch_size = 64
block_size = 128
n_embd = 512
n_layer = 12
n_head = 8
learning_rate = 3e-4
max_iters = 1000
eval_interval = 500


# Function to get a batch of data


def get_batch(split):
    try:
        data = train_data if split == 'train' else val_data
        ix = torch.randint(len(data) - block_size, (batch_size,))
        x = torch.stack([data[i:i+block_size] for i in ix])
        y = torch.stack([data[i+1:i+block_size+1] for i in ix])
        return x, y
    except Exception as e:
        print(f"Error in get_batch: {e}")
        raise


# Initialize the model
try:
    print("Initializing model...")
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = GPT(vocab_size, block_size, n_embd, n_layer, n_head).to(device)
    print(f"Model initialized on {device}.")
except Exception as e:
    print(f"Error in model initialization: {e}")
    raise

# Optimizer
try:
    print("Initializing optimizer...")
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
    print("Optimizer initialized.")
except Exception as e:
    print(f"Error in optimizer initialization: {e}")
    raise

# Training loop with time estimation
start_time = time.time()  # Record the start time
for step in range(max_iters):
    try:
        step_start_time = time.time()  # Start time of this step

        # Fetch training batch
        xb, yb = get_batch('train')
        xb, yb = xb.to(device), yb.to(device)

        # Forward pass
        logits, loss = model(xb, yb)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Debug info for training
        print(f"Step {step}: Train loss {loss.item():.4f}")

        # Evaluate periodically
        if step % eval_interval == 0 or step == max_iters - 1:
            with torch.no_grad():
                val_loss = sum(model(xb.to(device), yb.to(device))[1].item()
                               for xb, yb in [get_batch('val')] * 10) / 10

            # Calculate elapsed time and estimated remaining time
            elapsed_time = time.time() - start_time
            steps_completed = step + 1
            avg_step_time = elapsed_time / steps_completed
            remaining_time = avg_step_time * (max_iters - steps_completed)

            print(
                f"Step {step}: Train loss {loss.item():.4f}, Val loss {val_loss:.4f}")
            print(
                f"Elapsed time: {elapsed_time / 60:.2f} minutes, Estimated remaining time: {remaining_time / 60:.2f} minutes")

    except Exception as e:
        print(f"Error at step {step}: {e}")
        raise
# Out:
# Initializing model...
# Model initialized on cpu.
# Initializing optimizer...
# Optimizer initialized.
# Step 0: Train loss 4.6756
# Step 0: Train loss 4.6756, Val loss 4.1999
# Elapsed time: 0.29 minutes, Estimated remaining time: 288.19 minutes
# Step 1: Train loss 4.2544
# Step 2: Train loss 4.2775
# Step 3: Train loss 3.9784
# Step 4: Train loss 3.6295
# Step 5: Train loss 3.3766
# Step 6: Train loss 3.2106
# Step 7: Train loss 3.3015
# Step 8: Train loss 3.2798
# Step 9: Train loss 3.1774
# Step 10: Train loss 3.2018
# Step 11: Train loss 3.2113
# Step 12: Train loss 3.1399
# Step 13: Train loss 3.1927
# Step 14: Train loss 3.1583
# Step 15: Train loss 3.1308
# Step 16: Train loss 3.1329
# Step 17: Train loss 3.1509
# Step 18: Train loss 3.1688
# Step 19: Train loss 3.1329
# Step 20: Train loss 8.7314
# Step 21: Train loss 3.1097
# Step 22: Train loss 3.1146
# Step 23: Train loss 3.1546
# Step 24: Train loss 3.1428
# Step 25: Train loss 3.1292
# Step 26: Train loss 3.1610
# Step 27: Train loss 3.1348
# Step 28: Train loss 3.1551
# Step 29: Train loss 3.1446
# Step 30: Train loss 3.0954
# Step 31: Train loss 3.1630
# Step 32: Train loss 3.1178
# Step 33: Train loss 3.1091
# Step 34: Train loss 3.1315
# Step 35: Train loss 3.1381
# Step 36: Train loss 3.1266
# Step 37: Train loss 3.1442
# Step 38: Train loss 3.1401
# Step 39: Train loss 3.1462
# Step 40: Train loss 3.1416
# Step 41: Train loss 3.1756
# Step 42: Train loss 3.1058
# Step 43: Train loss 3.1123
# Step 44: Train loss 3.1253
# Step 45: Train loss 3.1119
# Step 46: Train loss 3.1116
# Step 47: Train loss 3.1659
# Step 48: Train loss 3.1069
# Step 49: Train loss 3.1140
# Step 50: Train loss 3.1154
# Step 51: Train loss 3.0914
# Step 52: Train loss 3.1202
# Step 53: Train loss 3.1607
# Step 54: Train loss 3.1032
# Step 55: Train loss 3.0967
# Step 56: Train loss 3.0983
# Step 57: Train loss 3.1021
# Step 58: Train loss 3.0915
# Step 59: Train loss 3.1112
# Step 60: Train loss 3.0980
# Step 61: Train loss 3.1233
# Step 62: Train loss 3.1332
# Step 63: Train loss 3.1146
# Step 64: Train loss 3.1226
# Step 65: Train loss 3.1055
# Step 66: Train loss 3.1335
# Step 67: Train loss 3.1353
# Step 68: Train loss 3.1541
# Step 69: Train loss 3.1234
# Step 70: Train loss 3.1013
# Step 71: Train loss 3.1062
# Step 72: Train loss 3.1069
# Step 73: Train loss 3.1459
# Step 74: Train loss 3.0912
# Step 75: Train loss 3.1385
# Step 76: Train loss 3.2026
# Step 77: Train loss 3.1253
# Step 78: Train loss 3.0802
# Step 79: Train loss 3.0877
# Step 80: Train loss 3.1075
# Step 81: Train loss 3.1186
# Step 82: Train loss 3.1501
# Step 83: Train loss 3.0944
# Step 84: Train loss 3.0890
# Step 85: Train loss 3.1401
# Step 86: Train loss 3.0943
# Step 87: Train loss 3.1238
# Step 88: Train loss 3.0879
# Step 89: Train loss 3.1059
# Step 90: Train loss 3.1258
# Step 91: Train loss 3.1108
# Step 92: Train loss 3.1146
# Step 93: Train loss 3.1181
# Step 94: Train loss 3.1388
# Step 95: Train loss 3.1217
# Step 96: Train loss 3.1005
# Step 97: Train loss 3.1180
# Step 98: Train loss 3.1059
# Step 99: Train loss 3.1201
# Step 100: Train loss 3.1171
# Step 101: Train loss 3.1101
# Step 102: Train loss 3.1166
# Step 103: Train loss 3.1171
# Step 104: Train loss 3.1198
# Step 105: Train loss 3.1240
# Step 106: Train loss 3.1047
# Step 107: Train loss 3.1109
# Step 108: Train loss 3.1143
# Step 109: Train loss 3.0954
# Step 110: Train loss 3.1033
# Step 111: Train loss 3.1230
# Step 112: Train loss 3.1422
# Step 113: Train loss 3.1083
# Step 114: Train loss 3.1103
# Step 115: Train loss 3.0938
# Step 116: Train loss 3.1200
# Step 117: Train loss 3.1229
# Step 118: Train loss 3.1484
# Step 119: Train loss 3.1064
# Step 120: Train loss 3.1176
# Step 121: Train loss 3.1507
# Step 122: Train loss 3.1440
# Step 123: Train loss 3.1077
# Step 124: Train loss 3.0963
# Step 125: Train loss 3.1132
# Step 126: Train loss 3.1545
# Step 127: Train loss 3.1133
# Step 128: Train loss 3.1279
# Step 129: Train loss 3.1090
# Step 130: Train loss 3.1096
# Step 131: Train loss 3.1026
# Step 132: Train loss 3.0899
# Step 133: Train loss 3.1460
# Step 134: Train loss 3.0987
# Step 135: Train loss 3.1268
# Step 136: Train loss 3.1297
# Step 137: Train loss 3.1341
# Step 138: Train loss 3.1092
# Step 139: Train loss 3.0962
# Step 140: Train loss 3.0997
# Step 141: Train loss 3.1018
# Step 142: Train loss 3.1153
# Step 143: Train loss 3.0904
# Step 144: Train loss 3.1625
# Step 145: Train loss 3.1207
# Step 146: Train loss 3.0868
# Step 147: Train loss 3.1139
# Step 148: Train loss 3.1185
# Step 149: Train loss 3.0888
# Step 150: Train loss 3.0755
# Step 151: Train loss 3.1583
# Step 152: Train loss 3.1332
# Step 153: Train loss 3.1444
# Step 154: Train loss 3.1057
# Step 155: Train loss 3.1129
# Step 156: Train loss 3.1430
# Step 157: Train loss 3.1248
# Step 158: Train loss 3.1243
# Step 159: Train loss 3.1605
# Step 160: Train loss 3.1454
# Step 161: Train loss 3.1269
# Step 162: Train loss 3.1097
# Step 163: Train loss 3.0892
# Step 164: Train loss 3.0804
# Step 165: Train loss 3.1183
# Step 166: Train loss 3.0993
# Step 167: Train loss 3.1241
# Step 168: Train loss 3.1023
# Step 169: Train loss 3.1040
# Step 170: Train loss 3.1246
# Step 171: Train loss 3.0933
# Step 172: Train loss 3.1179
# Step 173: Train loss 3.1098
# Step 174: Train loss 3.1532
# Step 175: Train loss 3.0798
# Step 176: Train loss 3.1184
# Step 177: Train loss 3.1011
# Step 178: Train loss 3.1310
# Step 179: Train loss 3.1333
# Step 180: Train loss 3.1217
# Step 181: Train loss 3.1482
# Step 182: Train loss 3.0719
# Step 183: Train loss 3.1001
# Step 184: Train loss 3.1098
# Step 185: Train loss 3.0889
# Step 186: Train loss 3.0927
# Step 187: Train loss 3.1240
# Step 188: Train loss 3.1311
# Step 189: Train loss 3.0989
# Step 190: Train loss 3.1065
# Step 191: Train loss 3.0939
# Step 192: Train loss 3.0763
# Step 193: Train loss 3.1195
# Step 194: Train loss 3.1377
# Step 195: Train loss 3.1176
# Step 196: Train loss 3.0863
# Step 197: Train loss 3.1379
# Step 198: Train loss 3.0941
# Step 199: Train loss 3.1205
# Step 200: Train loss 3.1140
# Step 201: Train loss 3.0977
# Step 202: Train loss 3.0976
# Step 203: Train loss 3.0952
# Step 204: Train loss 3.1163
# Step 205: Train loss 5.3612
# Step 206: Train loss 3.1401
# Step 207: Train loss 3.1165
# Step 208: Train loss 3.1484
# Step 209: Train loss 3.1139
# Step 210: Train loss 3.1090
# Step 211: Train loss 3.1087
# Step 212: Train loss 3.1284
# Step 213: Train loss 3.1233
# Step 214: Train loss 3.1978
# Step 215: Train loss 3.1248
# Step 216: Train loss 3.0881
# Step 217: Train loss 3.1120
# Step 218: Train loss 3.1284
# Step 219: Train loss 3.1661
# Step 220: Train loss 3.0853
# Step 221: Train loss 3.1123
# Step 222: Train loss 3.0991
# Step 223: Train loss 3.0907
# Step 224: Train loss 3.0824
# Step 225: Train loss 3.1427
# Step 226: Train loss 3.0850
# Step 227: Train loss 3.1073
# Step 228: Train loss 3.1381
# Step 229: Train loss 3.1237
# Step 230: Train loss 3.1444
# Step 231: Train loss 3.1267
# Step 232: Train loss 3.0869
# Step 233: Train loss 3.2129
# Step 234: Train loss 3.1270
# Step 235: Train loss 3.1119
# Step 236: Train loss 3.1216
# Step 237: Train loss 3.1430
# Step 238: Train loss 3.1263
# Step 239: Train loss 3.1458
# Step 240: Train loss 3.1101
# Step 241: Train loss 3.1266
# Step 242: Train loss 3.0738
# Step 243: Train loss 3.1060
# Step 244: Train loss 3.1653
# Step 245: Train loss 3.0969
# Step 246: Train loss 3.1411
# Step 247: Train loss 3.1558
# Step 248: Train loss 3.1247
# Step 249: Train loss 3.1341
# Step 250: Train loss 3.1077
# Step 251: Train loss 3.1101
# Step 252: Train loss 3.1005
# Step 253: Train loss 3.1782
# Step 254: Train loss 3.0911
# Step 255: Train loss 3.0892
# Step 256: Train loss 3.0926
# Step 257: Train loss 3.0893
# Step 258: Train loss 3.1151
# Step 259: Train loss 3.1155
# Step 260: Train loss 3.1150
# Step 261: Train loss 3.1437
# Step 262: Train loss 3.0908
# Step 263: Train loss 3.0908
# Step 264: Train loss 3.1630
# Step 265: Train loss 3.0868
# Step 266: Train loss 3.1951
# Step 267: Train loss 3.0928
# Step 268: Train loss 3.1255
# Step 269: Train loss 3.1886
# Step 270: Train loss 3.1810
# Step 271: Train loss 3.1366
# Step 272: Train loss 3.1023
# Step 273: Train loss 3.1184
# Step 274: Train loss 3.1224
# Step 275: Train loss 3.0845
# Step 276: Train loss 3.1013
# Step 277: Train loss 3.1827
# Step 278: Train loss 3.1006
# Step 279: Train loss 3.0967
# Step 280: Train loss 3.1169
# Step 281: Train loss 3.1331
# Step 282: Train loss 3.1233
# Step 283: Train loss 3.1257
# Step 284: Train loss 3.1310
# Step 285: Train loss 3.1374
# Step 286: Train loss 3.1053
# Step 287: Train loss 3.1002
# Step 288: Train loss 3.1003
# Step 289: Train loss 3.1169
# Step 290: Train loss 3.0947
# Step 291: Train loss 3.1222
# Step 292: Train loss 3.1395
# Step 293: Train loss 3.0862
# Step 294: Train loss 3.1011
# Step 295: Train loss 3.1028
# Step 296: Train loss 3.1233
# Step 297: Train loss 3.1607
# Step 298: Train loss 3.1782
# Step 299: Train loss 3.1481
# Step 300: Train loss 3.1036
# Step 301: Train loss 3.1810
# Step 302: Train loss 3.1404
# Step 303: Train loss 3.0952
# Step 304: Train loss 3.1442
# Step 305: Train loss 3.1267
# Step 306: Train loss 3.1257
# Step 307: Train loss 3.1108
# Step 308: Train loss 3.1069
# Step 309: Train loss 3.1378
# Step 310: Train loss 3.1253
# Step 311: Train loss 3.0944
# Step 312: Train loss 3.1115
# Step 313: Train loss 3.1689
# Step 314: Train loss 3.1051
# Step 315: Train loss 3.0843
# Step 316: Train loss 3.1307
# Step 317: Train loss 3.1192
# Step 318: Train loss 3.1419
# Step 319: Train loss 3.1096
# Step 320: Train loss 3.1337
# Step 321: Train loss 3.1075
# Step 322: Train loss 3.1199
# Step 323: Train loss 3.1190
# Step 324: Train loss 3.0900
# Step 325: Train loss 3.1202
# Step 326: Train loss 3.1155
# Step 327: Train loss 3.0810
# Step 328: Train loss 3.1417
# Step 329: Train loss 3.1632
# Step 330: Train loss 3.1070
# Step 331: Train loss 3.0887
# Step 332: Train loss 3.1210
# Step 333: Train loss 3.1208
# Step 334: Train loss 3.1156
# Step 335: Train loss 3.1050
# Step 336: Train loss 3.1346
# Step 337: Train loss 3.1259
# Step 338: Train loss 3.1058
# Step 339: Train loss 3.1083
# Step 340: Train loss 3.1331
# Step 341: Train loss 3.1168
# Step 342: Train loss 3.1118
# Step 343: Train loss 3.0954
# Step 344: Train loss 3.0986
# Step 345: Train loss 3.1240
# Step 346: Train loss 3.1054
# Step 347: Train loss 3.0913
# Step 348: Train loss 3.1353
# Step 349: Train loss 3.1250
# Step 350: Train loss 3.0946
# Step 351: Train loss 3.0995
# Step 352: Train loss 3.0832
# Step 353: Train loss 3.1153
# Step 354: Train loss 3.1206
# Step 355: Train loss 3.1703
# Step 356: Train loss 3.1013
# Step 357: Train loss 3.0970
# Step 358: Train loss 3.0959
# Step 359: Train loss 3.1414
# Step 360: Train loss 3.1188
# Step 361: Train loss 3.1143
# Step 362: Train loss 3.1170
# Step 363: Train loss 3.1514
# Step 364: Train loss 3.1080
# Step 365: Train loss 3.1071
# Step 366: Train loss 3.0810
# Step 367: Train loss 3.0972
# Step 368: Train loss 3.1169
# Step 369: Train loss 3.1321
# Step 370: Train loss 3.0843
# Step 371: Train loss 3.1225
# Step 372: Train loss 3.1213
# Step 373: Train loss 3.1008
# Step 374: Train loss 3.1160
# Step 375: Train loss 3.1265
# Step 376: Train loss 3.1053
# Step 377: Train loss 3.1038
# Step 378: Train loss 3.1374
# Step 379: Train loss 3.1094
# Step 380: Train loss 3.1000
# Step 381: Train loss 3.1142
# Step 382: Train loss 3.0848
# Step 383: Train loss 3.1065
# Step 384: Train loss 3.1170
# Step 385: Train loss 3.1110
# Step 386: Train loss 3.1223
# Step 387: Train loss 3.1024
# Step 388: Train loss 3.1357
# Step 389: Train loss 3.0823
# Step 390: Train loss 3.1157
# Step 391: Train loss 3.0890
# Step 392: Train loss 3.0898
# Step 393: Train loss 3.1015
# Step 394: Train loss 3.1051
# Step 395: Train loss 3.0934
# Step 396: Train loss 3.1146
# Step 397: Train loss 3.0838
# Step 398: Train loss 3.1243
# Step 399: Train loss 3.1085
# Step 400: Train loss 3.1321
# Step 401: Train loss 3.1047
# Step 402: Train loss 3.0992
# Step 403: Train loss 3.1133
# Step 404: Train loss 3.0765
# Step 405: Train loss 3.1129
# Step 406: Train loss 3.1148
# Step 407: Train loss 3.1207
# Step 408: Train loss 3.0992
# Step 409: Train loss 3.0867
# Step 410: Train loss 3.0687
# Step 411: Train loss 3.0929
# Step 412: Train loss 3.1367
# Step 413: Train loss 3.0934
# Step 414: Train loss 3.0999
# Step 415: Train loss 3.1129
# Step 416: Train loss 3.1337
# Step 417: Train loss 3.1334
# Step 418: Train loss 3.0878
# Step 419: Train loss 3.1294
# Step 420: Train loss 3.0883
# Step 421: Train loss 3.1178
# Step 422: Train loss 3.0916
# Step 423: Train loss 3.1152
# Step 424: Train loss 3.0805
# Step 425: Train loss 3.1111
# Step 426: Train loss 3.0746
# Step 427: Train loss 3.0918
# Step 428: Train loss 3.1274
# Step 429: Train loss 3.0811
# Step 430: Train loss 3.0648
# Step 431: Train loss 3.1392
# Step 432: Train loss 3.1087
# Step 433: Train loss 3.0946
# Step 434: Train loss 3.1218
# Step 435: Train loss 3.0740
# Step 436: Train loss 3.0974
# Step 437: Train loss 3.0927
# Step 438: Train loss 3.1122
# Step 439: Train loss 3.1405
# Step 440: Train loss 3.0964
# Step 441: Train loss 3.0731
# Step 442: Train loss 3.1026
# Step 443: Train loss 3.0767
# Step 444: Train loss 3.0823
# Step 445: Train loss 3.0918
# Step 446: Train loss 3.0819
# Step 447: Train loss 3.1259
# Step 448: Train loss 3.1057
# Step 449: Train loss 3.1293
# Step 450: Train loss 3.0892
# Step 451: Train loss 3.1209
# Step 452: Train loss 3.1359
# Step 453: Train loss 3.1046
# Step 454: Train loss 3.0876
# Step 455: Train loss 3.1128
# Step 456: Train loss 3.1065
# Step 457: Train loss 3.1076
# Step 458: Train loss 3.0980
# Step 459: Train loss 3.1105
# Step 460: Train loss 3.1043
# Step 461: Train loss 3.1429
# Step 462: Train loss 3.1173
# Step 463: Train loss 3.1103
# Step 464: Train loss 3.0946
# Step 465: Train loss 3.1308
# Step 466: Train loss 3.1577
# Step 467: Train loss 3.1005
# Step 468: Train loss 3.1020
# Step 469: Train loss 3.1121
# Step 470: Train loss 3.1668
# Step 471: Train loss 3.1631
# Step 472: Train loss 3.1244
# Step 473: Train loss 3.0721
# Step 474: Train loss 3.1100
# Step 475: Train loss 3.0921
# Step 476: Train loss 3.1366
# Step 477: Train loss 3.1207
# Step 478: Train loss 3.1191
# Step 479: Train loss 3.0944
# Step 480: Train loss 3.1269
# Step 481: Train loss 3.1478
# Step 482: Train loss 3.1098
# Step 483: Train loss 3.0946
# Step 484: Train loss 3.0779
# Step 485: Train loss 3.1191
# Step 486: Train loss 3.0927
# Step 487: Train loss 3.1303
# Step 488: Train loss 3.0811
# Step 489: Train loss 3.1069
# Step 490: Train loss 3.0755
# Step 491: Train loss 3.0867
# Step 492: Train loss 3.1282
# Step 493: Train loss 3.1129
# Step 494: Train loss 3.1045
# Step 495: Train loss 3.1288
# Step 496: Train loss 3.1201
# Step 497: Train loss 3.1214
# Step 498: Train loss 3.1154
# Step 499: Train loss 3.1073
# Step 500: Train loss 3.1150
# Step 500: Train loss 3.1150, Val loss 3.1342
# Elapsed time: 37.55 minutes, Estimated remaining time: 37.40 minutes
# Step 501: Train loss 3.0913
# Step 502: Train loss 3.1043
# Step 503: Train loss 3.1082
# Step 504: Train loss 3.1375
# Step 505: Train loss 3.1131
# Step 506: Train loss 3.1311
# Step 507: Train loss 3.1127
# Step 508: Train loss 3.1660
# Step 509: Train loss 3.1126
# Step 510: Train loss 3.1095
# Step 511: Train loss 3.1312
# Step 512: Train loss 3.1292
# Step 513: Train loss 3.1348
# Step 514: Train loss 3.1038
# Step 515: Train loss 3.1648
# Step 516: Train loss 3.1328
# Step 517: Train loss 3.0906
# Step 518: Train loss 3.1137
# Step 519: Train loss 3.0890
# Step 520: Train loss 3.1105
# Step 521: Train loss 3.1787
# Step 522: Train loss 3.1058
# Step 523: Train loss 3.1595
# Step 524: Train loss 3.1331
# Step 525: Train loss 3.1171
# Step 526: Train loss 3.1182
# Step 527: Train loss 3.0886
# Step 528: Train loss 3.1488
# Step 529: Train loss 3.1617
# Step 530: Train loss 3.1244
# Step 531: Train loss 3.0803
# Step 532: Train loss 3.1099
# Step 533: Train loss 3.1310
# Step 534: Train loss 3.1051
# Step 535: Train loss 3.1005
# Step 536: Train loss 3.1516
# Step 537: Train loss 3.1350
# Step 538: Train loss 3.1608
# Step 539: Train loss 3.1079
# Step 540: Train loss 3.1266
# Step 541: Train loss 3.1580
# Step 542: Train loss 3.0939
# Step 543: Train loss 3.1278
# Step 544: Train loss 3.1261
# Step 545: Train loss 3.0904
# Step 546: Train loss 3.0942
# Step 547: Train loss 3.0889
# Step 548: Train loss 3.0850
# Step 549: Train loss 3.1088
# Step 550: Train loss 3.1183
# Step 551: Train loss 3.1768
# Step 552: Train loss 3.1050
# Step 553: Train loss 3.1357
# Step 554: Train loss 3.1099
# Step 555: Train loss 3.1101
# Step 556: Train loss 3.1212
# Step 557: Train loss 3.1144
# Step 558: Train loss 3.0798
# Step 559: Train loss 3.1353
# Step 560: Train loss 3.1087
# Step 561: Train loss 3.0891
# Step 562: Train loss 3.1067
# Step 563: Train loss 3.1293
# Step 564: Train loss 3.0890
# Step 565: Train loss 3.0981
# Step 566: Train loss 3.1194
# Step 567: Train loss 3.0980
# Step 568: Train loss 3.0973
# Step 569: Train loss 3.1333
# Step 570: Train loss 3.0981
# Step 571: Train loss 3.1069
# Step 572: Train loss 3.1513
# Step 573: Train loss 3.1041
# Step 574: Train loss 3.1565
# Step 575: Train loss 3.0941
# Step 576: Train loss 3.1170
# Step 577: Train loss 3.1117
# Step 578: Train loss 3.0836
# Step 579: Train loss 3.1108
# Step 580: Train loss 3.1357
# Step 581: Train loss 3.1095
# Step 582: Train loss 3.0867
# Step 583: Train loss 3.1291
# Step 584: Train loss 3.1402
# Step 585: Train loss 3.1077
# Step 586: Train loss 3.0844
# Step 587: Train loss 3.1117
# Step 588: Train loss 3.1068
# Step 589: Train loss 3.1017
# Step 590: Train loss 3.0885
# Step 591: Train loss 3.0937
# Step 592: Train loss 3.1104
# Step 593: Train loss 3.1021
# Step 594: Train loss 3.0616
# Step 595: Train loss 3.0900
# Step 596: Train loss 3.1166
# Step 597: Train loss 3.1061
# Step 598: Train loss 3.0830
# Step 599: Train loss 3.1271
# Step 600: Train loss 3.1134
# Step 601: Train loss 3.1084
# Step 602: Train loss 3.1177
# Step 603: Train loss 3.0943
# Step 604: Train loss 3.1176
# Step 605: Train loss 3.0854
# Step 606: Train loss 3.0851
# Step 607: Train loss 3.1060
# Step 608: Train loss 3.1799
# Step 609: Train loss 3.1580
# Step 610: Train loss 3.1023
# Step 611: Train loss 3.1175
# Step 612: Train loss 3.1583
# Step 613: Train loss 3.1248
# Step 614: Train loss 3.1003
# Step 615: Train loss 3.1207
# Step 616: Train loss 3.1153
# Step 617: Train loss 3.1324
# Step 618: Train loss 3.0869
# Step 619: Train loss 3.0889
# Step 620: Train loss 3.0934
# Step 621: Train loss 3.1145
# Step 622: Train loss 3.1179
# Step 623: Train loss 3.1119
# Step 624: Train loss 3.1570
# Step 625: Train loss 3.1052
# Step 626: Train loss 3.1129
# Step 627: Train loss 3.0959
# Step 628: Train loss 3.0884
# Step 629: Train loss 3.1214
# Step 630: Train loss 3.1027
# Step 631: Train loss 3.1130
# Step 632: Train loss 3.1272
# Step 633: Train loss 3.1029
# Step 634: Train loss 3.1281
# Step 635: Train loss 3.1456
# Step 636: Train loss 3.1006
# Step 637: Train loss 3.0708
# Step 638: Train loss 3.1410
# Step 639: Train loss 3.0999
# Step 640: Train loss 3.1515
# Step 641: Train loss 3.1165
# Step 642: Train loss 3.0963
# Step 643: Train loss 3.1369
# Step 644: Train loss 3.0853
# Step 645: Train loss 3.1488
# Step 646: Train loss 3.1013
# Step 647: Train loss 3.0872
# Step 648: Train loss 3.1140
# Step 649: Train loss 3.1431
# Step 650: Train loss 3.0845
# Step 651: Train loss 3.1515
# Step 652: Train loss 3.1275
# Step 653: Train loss 3.1176
# Step 654: Train loss 3.0962
# Step 655: Train loss 3.1486
# Step 656: Train loss 3.1323
# Step 657: Train loss 3.0982
# Step 658: Train loss 3.1246
# Step 659: Train loss 3.1411
# Step 660: Train loss 3.1066
# Step 661: Train loss 3.1177
# Step 662: Train loss 3.1059
# Step 663: Train loss 3.1084
# Step 664: Train loss 3.1774
# Step 665: Train loss 3.1291
# Step 666: Train loss 3.1157
# Step 667: Train loss 3.0843
# Step 668: Train loss 3.1062
# Step 669: Train loss 3.1111
# Step 670: Train loss 3.0994
# Step 671: Train loss 3.1171
# Step 672: Train loss 3.0889
# Step 673: Train loss 3.0978
# Step 674: Train loss 3.1158
# Step 675: Train loss 3.1182
# Step 676: Train loss 3.1351
# Step 677: Train loss 3.0987
# Step 678: Train loss 3.1097
# Step 679: Train loss 3.1495
# Step 680: Train loss 3.1202
# Step 681: Train loss 3.0987
# Step 682: Train loss 3.0904
# Step 683: Train loss 3.0845
# Step 684: Train loss 3.1188
# Step 685: Train loss 3.0990
# Step 686: Train loss 3.1198
# Step 687: Train loss 3.0949
# Step 688: Train loss 3.1063
# Step 689: Train loss 3.1411
# Step 690: Train loss 3.0822
# Step 691: Train loss 3.1089
# Step 692: Train loss 3.1104
# Step 693: Train loss 3.1281
# Step 694: Train loss 3.0992
# Step 695: Train loss 3.1164
# Step 696: Train loss 3.0771
# Step 697: Train loss 3.0814
# Step 698: Train loss 3.1455
# Step 699: Train loss 3.0736
# Step 700: Train loss 3.0880
# Step 701: Train loss 3.0806
# Step 702: Train loss 3.0808
# Step 703: Train loss 3.1181
# Step 704: Train loss 3.1493
# Step 705: Train loss 3.1298
# Step 706: Train loss 3.1027
# Step 707: Train loss 3.1083
# Step 708: Train loss 3.0905
# Step 709: Train loss 3.1006
# Step 710: Train loss 3.0825
# Step 711: Train loss 3.0949
# Step 712: Train loss 3.0924
# Step 713: Train loss 3.1408
# Step 714: Train loss 3.0971
# Step 715: Train loss 3.1165
# Step 716: Train loss 3.1514
# Step 717: Train loss 3.1541
# Step 718: Train loss 3.0928
# Step 719: Train loss 3.1304
# Step 720: Train loss 3.1354
# Step 721: Train loss 3.0969
# Step 722: Train loss 3.1149
# Step 723: Train loss 3.1261
# Step 724: Train loss 3.0745
# Step 725: Train loss 3.0968
# Step 726: Train loss 3.1339
# Step 727: Train loss 3.0855
# Step 728: Train loss 3.1493
# Step 729: Train loss 3.1411
# Step 730: Train loss 3.0953
# Step 731: Train loss 3.0889
# Step 732: Train loss 3.1225
# Step 733: Train loss 3.1222
# Step 734: Train loss 3.1121
# Step 735: Train loss 3.0999
# Step 736: Train loss 3.0981
# Step 737: Train loss 3.0770
# Step 738: Train loss 3.1131
# Step 739: Train loss 3.1201
# Step 740: Train loss 3.1098
# Step 741: Train loss 3.0992
# Step 742: Train loss 3.0990
# Step 743: Train loss 3.1691
# Step 744: Train loss 3.0950
# Step 745: Train loss 3.1261
# Step 746: Train loss 3.1007
# Step 747: Train loss 3.0976
# Step 748: Train loss 3.1599
# Step 749: Train loss 3.1016
# Step 750: Train loss 3.1004
# Step 751: Train loss 3.1119
# Step 752: Train loss 3.1176
# Step 753: Train loss 3.1003
# Step 754: Train loss 3.1113
# Step 755: Train loss 3.1502
# Step 756: Train loss 3.1234
# Step 757: Train loss 3.1023
# Step 758: Train loss 3.1083
# Step 759: Train loss 3.1140
# Step 760: Train loss 3.1049
# Step 761: Train loss 3.1564
# Step 762: Train loss 3.1031
# Step 763: Train loss 3.1395
# Step 764: Train loss 3.0973
# Step 765: Train loss 3.1451
# Step 766: Train loss 3.1141
# Step 767: Train loss 3.0623
# Step 768: Train loss 3.0873
# Step 769: Train loss 3.1379
# Step 770: Train loss 3.1245
# Step 771: Train loss 3.0886
# Step 772: Train loss 3.0829
# Step 773: Train loss 3.1058
# Step 774: Train loss 3.0883
# Step 775: Train loss 3.1574
# Step 776: Train loss 3.0816
# Step 777: Train loss 3.1450
# Step 778: Train loss 3.1295
# Step 779: Train loss 3.1056
# Step 780: Train loss 3.1237
# Step 781: Train loss 3.0887
# Step 782: Train loss 3.0809
# Step 783: Train loss 3.1198
# Step 784: Train loss 3.1169
# Step 785: Train loss 3.0992
# Step 786: Train loss 3.0943
# Step 787: Train loss 3.0873
# Step 788: Train loss 3.1114
# Step 789: Train loss 3.1182
# Step 790: Train loss 3.0979
# Step 791: Train loss 3.0797
# Step 792: Train loss 3.1056
# Step 793: Train loss 3.1975
# Step 794: Train loss 3.1017
# Step 795: Train loss 3.0949
# Step 796: Train loss 3.0996
# Step 797: Train loss 3.1564
# Step 798: Train loss 3.1153
# Step 799: Train loss 3.1355
# Step 800: Train loss 3.1339
# Step 801: Train loss 3.1167
# Step 802: Train loss 3.0773
# Step 803: Train loss 3.0767
# Step 804: Train loss 3.1186
# Step 805: Train loss 3.0797
# Step 806: Train loss 3.0986
# Step 807: Train loss 3.0928
# Step 808: Train loss 3.0828
# Step 809: Train loss 3.0881
# Step 810: Train loss 3.0907
# Step 811: Train loss 3.1237
# Step 812: Train loss 3.1314
# Step 813: Train loss 3.0701
# Step 814: Train loss 3.1145
# Step 815: Train loss 3.1122
# Step 816: Train loss 3.0859
# Step 817: Train loss 3.1042
# Step 818: Train loss 3.0812
# Step 819: Train loss 3.0913
# Step 820: Train loss 3.1482
# Step 821: Train loss 3.1212
# Step 822: Train loss 3.1055
# Step 823: Train loss 3.1099
# Step 824: Train loss 3.0804
# Step 825: Train loss 3.1275
# Step 826: Train loss 3.1052
# Step 827: Train loss 3.1128
# Step 828: Train loss 3.1323
# Step 829: Train loss 3.1031
# Step 830: Train loss 3.1564
# Step 831: Train loss 3.1420
# Step 832: Train loss 3.1435
# Step 833: Train loss 3.1213
# Step 834: Train loss 3.0733
# Step 835: Train loss 3.0954
# Step 836: Train loss 3.0962
# Step 837: Train loss 3.0956
# Step 838: Train loss 3.1211
# Step 839: Train loss 3.1239
# Step 840: Train loss 3.1114
# Step 841: Train loss 3.0726
# Step 842: Train loss 3.1045
# Step 843: Train loss 3.1509
# Step 844: Train loss 3.1067
# Step 845: Train loss 3.1176
# Step 846: Train loss 3.0962
# Step 847: Train loss 3.1151
# Step 848: Train loss 3.1041
# Step 849: Train loss 3.1326
# Step 850: Train loss 3.1039
# Step 851: Train loss 3.1066
# Step 852: Train loss 3.1179
# Step 853: Train loss 3.1482
# Step 854: Train loss 3.1092
# Step 855: Train loss 3.1219
# Step 856: Train loss 3.1447
# Step 857: Train loss 3.1039
# Step 858: Train loss 3.1271
# Step 859: Train loss 3.0995
# Step 860: Train loss 3.0907
# Step 861: Train loss 3.1513
# Step 862: Train loss 3.0883
# Step 863: Train loss 3.1489
# Step 864: Train loss 3.1358
# Step 865: Train loss 3.1188
# Step 866: Train loss 3.0574
# Step 867: Train loss 3.0860
# Step 868: Train loss 3.1289
# Step 869: Train loss 3.1740
# Step 870: Train loss 3.1419
# Step 871: Train loss 3.1177
# Step 872: Train loss 3.1297
# Step 873: Train loss 3.0926
# Step 874: Train loss 3.1166
# Step 875: Train loss 3.1168
# Step 876: Train loss 3.1489
# Step 877: Train loss 3.0958
# Step 878: Train loss 3.1560
# Step 879: Train loss 3.0925
# Step 880: Train loss 3.1184
# Step 881: Train loss 3.0979
# Step 882: Train loss 3.1383
# Step 883: Train loss 3.1172
# Step 884: Train loss 3.1557
# Step 885: Train loss 3.0780
# Step 886: Train loss 3.1529
# Step 887: Train loss 3.1329
# Step 888: Train loss 3.0989
# Step 889: Train loss 3.1006
# Step 890: Train loss 3.0784
# Step 891: Train loss 3.1267
# Step 892: Train loss 3.0978
# Step 893: Train loss 3.1261
# Step 894: Train loss 3.1267
# Step 895: Train loss 3.1550
# Step 896: Train loss 3.0658
# Step 897: Train loss 3.1067
# Step 898: Train loss 3.1408
# Step 899: Train loss 3.1589
# Step 900: Train loss 3.1577
# Step 901: Train loss 3.0692
# Step 902: Train loss 3.0867
# Step 903: Train loss 3.1382
# Step 904: Train loss 3.1129
# Step 905: Train loss 3.1026
# Step 906: Train loss 3.1074
# Step 907: Train loss 3.1173
# Step 908: Train loss 3.0943
# Step 909: Train loss 3.1164
# Step 910: Train loss 3.1262
# Step 911: Train loss 3.0759
# Step 912: Train loss 3.0781
# Step 913: Train loss 3.1041
# Step 914: Train loss 3.0800
# Step 915: Train loss 3.0903
# Step 916: Train loss 3.1383
# Step 917: Train loss 3.1187
# Step 918: Train loss 3.0935
# Step 919: Train loss 3.1033
# Step 920: Train loss 3.1681
# Step 921: Train loss 3.1697
# Step 922: Train loss 3.1101
# Step 923: Train loss 3.1383
# Step 924: Train loss 3.1158
# Step 925: Train loss 3.0855
# Step 926: Train loss 3.1038
# Step 927: Train loss 3.1241
# Step 928: Train loss 3.1454
# Step 929: Train loss 3.1728
# Step 930: Train loss 3.1077
# Step 931: Train loss 3.1277
# Step 932: Train loss 3.1121
# Step 933: Train loss 3.1096
# Step 934: Train loss 3.1275
# Step 935: Train loss 3.1238
# Step 936: Train loss 3.1110
# Step 937: Train loss 3.0846
# Step 938: Train loss 3.0847
# Step 939: Train loss 3.1078
# Step 940: Train loss 3.1150
# Step 941: Train loss 3.1170
# Step 942: Train loss 3.1119
# Step 943: Train loss 3.1031
# Step 944: Train loss 3.1946
# Step 945: Train loss 3.1263
# Step 946: Train loss 3.1457
# Step 947: Train loss 3.1223
# Step 948: Train loss 3.1132
# Step 949: Train loss 3.1080
# Step 950: Train loss 3.1313
# Step 951: Train loss 3.1074
# Step 952: Train loss 3.0920
# Step 953: Train loss 3.1461
# Step 954: Train loss 3.0950
# Step 955: Train loss 3.1155
# Step 956: Train loss 3.1034
# Step 957: Train loss 3.1418
# Step 958: Train loss 3.1506
# Step 959: Train loss 3.0907
# Step 960: Train loss 3.1189
# Step 961: Train loss 3.0841
# Step 962: Train loss 3.1781
# Step 963: Train loss 3.1295
# Step 964: Train loss 3.1593
# Step 965: Train loss 3.1094
# Step 966: Train loss 3.1347
# Step 967: Train loss 3.1240
# Step 968: Train loss 3.1304
# Step 969: Train loss 3.0790
# Step 970: Train loss 3.0843
# Step 971: Train loss 3.1358
# Step 972: Train loss 3.1235
# Step 973: Train loss 3.0895
# Step 974: Train loss 3.0897
# Step 975: Train loss 3.1490
# Step 976: Train loss 3.1284
# Step 977: Train loss 3.0918
# Step 978: Train loss 3.0900
# Step 979: Train loss 3.0988
# Step 980: Train loss 3.1357
# Step 981: Train loss 3.0925
# Step 982: Train loss 3.1074
# Step 983: Train loss 3.0973
# Step 984: Train loss 3.1309
# Step 985: Train loss 3.1290
# Step 986: Train loss 3.1081
# Step 987: Train loss 3.0866
# Step 988: Train loss 3.1205
# Step 989: Train loss 3.1847
# Step 990: Train loss 3.1477
# Step 991: Train loss 3.0923
# Step 992: Train loss 3.1212
# Step 993: Train loss 3.1038
# Step 994: Train loss 3.1275
# Step 995: Train loss 3.1415
# Step 996: Train loss 3.1444
# Step 997: Train loss 3.0949
# Step 998: Train loss 3.0939
# Step 999: Train loss 3.0844
# Step 999: Train loss 3.0844, Val loss 3.1780
# Elapsed time: 74.87 minutes, Estimated remaining time: 0.00 minutes

# %%
def generate(model, start, max_new_tokens):
    model.eval()
    with torch.no_grad():
        idx = torch.tensor(encode(start), dtype=torch.long,
                           device=device).unsqueeze(0)
        for _ in range(max_new_tokens):
            logits = model(idx)[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            next_token = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, next_token), dim=1)
        return decode(idx[0].tolist())


# Generate text
print(generate(model, start="Whale", max_new_tokens=100))
# Out:
# Whaleu spaya i novr grwl t“icecidwmyitreeaesGki,0e o g h oig,tt og emiat g s It thl a sfagoete  ”gc i  od
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
